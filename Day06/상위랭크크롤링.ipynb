# %% [markdown]
# 해결문제)
#
# daum 영화 사이트에서 현재 상영작의 목록을 추출하고 상영영화를 선택하면 해당 영화의 상위 10개의 리뷰 내용을 감성분석하시오.
# + https://movie.daum.net/premovie/released

# %%
#한글 폰트 사용 : colab , 런타임 다시 시작 하기
# %config InlineBackend.figure_format = 'retina'

# !apt -qq -y install fonts-nanum
# Out:
# fonts-nanum is already the newest version (20170925-1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 33 not upgraded.

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup as bs

import matplotlib.pyplot as plt

import matplotlib as mpl
import matplotlib.font_manager as fm
fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=9)
plt.rc('font', family='NanumBarunGothic') 
mpl.font_manager._rebuild()

import re

# %%
#문자열에서 charset요소값을 찾아줌
def charEncode(st) :
    pt = r'charset=[\"\']*([\w-]+)'

    charcode  = re.search(pt, st)
    if charcode : 
        cc = charcode.group(1)
    else :
        cc = 'utf-8'

    return cc

#해당 페이지를 decode한 html문서 가져오기
def urlHtml(url):
    data = urlopen(url).read()
    urlcc = charEncode(str(data))
    html = data.decode(urlcc, errors="replace")

    html = bs(html, 'html.parser')
    return html

# %%
def mvlist() :
    mvlt = [] 
    url = 'https://movie.daum.net/premovie/released'
    html = urlHtml(url)
    ul = html.select('.list_boxthumb > li')

    for li in ul :
      lilt = []
      ainfo = str(li.select_one('a'))
      id = re.search(r'data-tiara-id=\"([\d]+)', ainfo).group(1)
      rank = re.search(r'data-tiara-ordnum=\"([\d]+)', ainfo)
      href = re.search(r'href=\"([\w\/?=]+)', ainfo).group(1)

        #영화명 : 태그로 찾기
      mvname = li.select_one('strong').text.replace(',', '')

      lilt.append(id)
      lilt.append(href)
      lilt.append(mvname)
      mvlt.append(lilt)

    return mvlt

# %%
temp = mvlist()
print(temp)
# Out:
# [['134684', '/moviedb/main?movieId=134684', '#살아있다'], ['136058', '/moviedb/main?movieId=136058', '밤쉘: 세상을 바꾼 폭탄선언'], ['57958', '/moviedb/main?movieId=57958', '다크 나이트 라이즈'], ['131537', '/moviedb/main?movieId=131537', '소년시절의 너'], ['129134', '/moviedb/main?movieId=129134', '온워드: 단 하루의 기적'], ['126126', '/moviedb/main?movieId=126126', '결백'], ['59154', '/moviedb/main?movieId=59154', '원 데이'], ['141035', '/moviedb/main?movieId=141035', '불량한 가족'], ['134682', '/moviedb/main?movieId=134682', '소리꾼'], ['131049', '/moviedb/main?movieId=131049', '너와 파도를 탈 수 있다면'], ['135059', '/moviedb/main?movieId=135059', '그레텔과 헨젤'], ['141950', '/moviedb/main?movieId=141950', '아무튼 아담'], ['141781', '/moviedb/main?movieId=141781', '딥워터'], ['53080', '/moviedb/main?movieId=53080', '위대한 쇼맨'], ['37066', '/moviedb/main?movieId=37066', '트로이 디렉터스 컷'], ['43569', '/moviedb/main?movieId=43569', '다크 나이트'], ['126263', '/moviedb/main?movieId=126263', '팡파레'], ['118873', '/moviedb/main?movieId=118873', '트랜짓'], ['126413', '/moviedb
# ...

# %% [markdown]
# https://movie.daum.net/moviedb/grade?movieId=136058

# %%
def review(movieid):
    url = 'https://movie.daum.net/moviedb/grade?movieId='
    url= url + i
    #url = 'https://movie.daum.net/moviedb/grade?movieId=136058'
    html = urlHtml(url)
    talkmv = html.select('.list_review > li')
    for item in talkmv :
      desc_review = item.select_one('.desc_review').text
      desc_review = desc_review.strip().replace('\n', '')
      mvtalk.append(desc_review)
    print(mvtalk)
    return mvtalk

# %%
data = mvlist()
movieid=[]
mvtalk = []
pp = []
tp = {}

for line in data :
  movieid.append(line[0]) #리뷰를 볼 영화의 movieid 리스트
print(movieid)

for item in movieid :
  pp.append( review(item))
  tp[item]=pp

print(tp)
# Out:
# ['134684', '136058', '57958', '131537', '129134', '126126', '59154', '141035', '134682', '131049', '135059', '141950', '141781', '53080', '37066', '43569', '39094', '126263', '118873', '126413']
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-56-4917556a026c> in <module>()
#      10
#      11 for item in movieid :
# ---> 12   pp.append( review(item))
#      13   tp[item]=pp
#      14
#
# <ipython-input-54-357e2230b61c> in review(movieid)
#       3     url= url + i
#       4     #url = 'https://movie.daum.net/moviedb/grade?movieId=136058'
# ----> 5     html = urlHtml(url)
#       6     talkmv = html.select('.list_review > li')
#       7     for item in talkmv :
#
# <ipython-input-3-c0c277cf937c> in urlHtml(url)
#      13 #해당 페이지를 decode한 html문서 가져오기
#      14 def urlHtml(url):
# ---> 15     data = urlopen(url).read()
#      16     urlcc = charEncode(str(data))
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# ---------------------------------------------------------------------------
# TIMEOUT                                   Traceback (most recent call last)
# <ipython-input-57-d5df0069828e> in <module>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.6/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, use_metadata_server)
#     222         oauth_prompt,
# ...
