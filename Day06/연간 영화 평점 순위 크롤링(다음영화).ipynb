# %% [markdown]
# 해결문제)
#
# daum 영화 사이트에서 2018, 2019년 박스 오피스 정보를 추출하여 텍스트 파일을 작성하시오,
# 작성된 텍스트 파일을 읽어서 년도별 박스 오피스의 순위별 평점 현황을 그래프로 그리시오.
# + https://movie.daum.net/boxoffice/yearly
#
#
# ```
# 2018,'신과함께-인과 연', 6.8, '2018.08.01'
# 2018,'어벤져스: 인피니티 워', 7.6, '2018.04.25'
# 2018,'보헤미안 랩소디', 8.9, '2018.10.31'
# 2018,'미션 임파서블: 폴아웃', 8.1, '2018.07.25'
# 2018,'신과함께-죄와 벌', 7.0, '2017.12.20'
# 2018,'쥬라기 월드: 폴른 킹덤', 7.1, '2018.06.06'
# ```

# %%
#한글 폰트 사용 : colab , 런타임 다시 시작 하기
# %config InlineBackend.figure_format = 'retina'
# !apt -qq -y install fonts-nanum
# Out:
# fonts-nanum is already the newest version (20170925-1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 33 not upgraded.

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup as bs

import matplotlib.pyplot as plt

import matplotlib as mpl
import matplotlib.font_manager as fm
fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=9)
plt.rc('font', family='NanumBarunGothic') 
mpl.font_manager._rebuild()

import re

# %%
#문자열에서 charset요소값을 찾아줌
def charEncode(st) :
    pt = r'charset=[\"\']*([\w-]+)'

    charcode  = re.search(pt, st)
    if charcode : 
        cc = charcode.group(1)
    else :
        cc = 'utf-8'

    return cc

#해당 페이지를 decode한 html문서 가져오기
def urlHtml(url):
    data = urlopen(url).read()
    urlcc = charEncode(str(data))
    html = data.decode(urlcc, errors="replace")

    html = bs(html, 'html.parser')
    return html

# %%
def mvlist(year):
    mvlt = [] 
    url = 'https://movie.daum.net/boxoffice/yearly?year=' + str(year)

    html = urlHtml(url)
    ul = html.select('.list_boxthumb > li')
  
    for li in ul :
      lilt=[]
      ainfo = str(li.select_one('a'))
      id = re.search(r'data-tiara-id=\"([\d]+)', ainfo).group(1)
      rank = re.search(r'data-tiara-ordnum=\"([\d]+)', ainfo).group(1)
      href = re.search(r'href=\"([\w\/?=]+)', ainfo).group(1)
      mvname = li.select_one('strong').text.replace(',', '') #영화명에 ,가 있는 걸 삭제
      grade = li.select_one('.emph_grade').text
      openday=li.select_one('dd').text
      
      lilt.append(id)
      lilt.append(rank)
      lilt.append(href)
      lilt.append(mvname)
      lilt.append(float(grade))
      lilt.append(openday[:10])

      mvlt.append(lilt)

    return mvlt

# %%
mvlist(2019)
# Out:
# [['119859', '1', '/moviedb/main?movieId=119859', '극한직업', 7.4, '2019.01.23'],
#  ['93252',
#   '2',
#   '/moviedb/main?movieId=93252',
#   '어벤져스: 엔드게임',
#   7.8,
#   '2019.04.24'],
#  ['93004', '3', '/moviedb/main?movieId=93004', '겨울왕국 2', 7.4, '2019.11.21'],
#  ['115601', '4', '/moviedb/main?movieId=115601', '알라딘', 8.4, '2019.05.23'],
#  ['111292', '5', '/moviedb/main?movieId=111292', '기생충', 7.9, '2019.05.30'],
#  ['121137', '6', '/moviedb/main?movieId=121137', '엑시트', 7.7, '2019.07.31'],
#  ['122542',
#   '7',
#   '/moviedb/main?movieId=122542',
#   '스파이더맨: 파 프롬 홈',
#   6.5,
#   '2019.07.02'],
#  ['133855', '8', '/moviedb/main?movieId=133855', '백두산', 6.5, '2019.12.19'],
#  ['101393', '9', '/moviedb/main?movieId=101393', '캡틴 마블', 6.3, '2019.03.06'],
#  ['125080', '10', '/moviedb/main?movieId=125080', '조커', 7.7, '2019.10.02'],
#  ['121160', '11', '/moviedb/main?movieId=121160', '봉오동 전투', 8.8, '2019.08.07'],
#  ['116523', '12', '/moviedb/main?movieId=116523', '라이온 킹', 7.4, '2019.07.17'],
#  ['123374',
#   '13',
#   '/moviedb/main?movieId=123374',
#   '나쁜 녀석들: 더 무비',
#   6.3,
#   '2019.09.11'],
#  ['124806',
#   '14',
#   '/moviedb/main?movieId=124806',
#   '82년생 김지영',
#   6.7,
#   '2019.10.23'],
#  ['127242',
#   '15',
#   '/moviedb/main?movieId=127242',
#   '분노의 질주: 홉스&쇼',
#   7.0,
#   '2019.08.14'],
#  ['123556',
#   '16',
#   '/moviedb/main?movieId=123556',
#   '토이 스토리 4',
#   8.6,
#   '2019.06.20'],
#  ['110875', '17', '/moviedb/main?movieId=110875', '돈', 6.7, '2019.03.20'],
#  ['121919', '18', '/moviedb/main?movieId=121919', '악인전', 7.4, '2019.05.15'],
#  ['127878',
#   '19',
#   '/moviedb/main?movieId=127878',
#   '가장 보통의 연애',
#   7.4,
#   '2019.10.02'],
#  ['118907', '20', '/moviedb/main?movieId=118907', '말모이', 9.1, '2019.01.09'],
#  ['121408', '21', '/moviedb/main?movieId=121408', '증인', 9.3, '2019.02.13'],
#  ['128397', '22', '/moviedb/main?movieId=128397', '시동', 7.6, '2019.12.18'],
#  ['134130', '23', '/moviedb/main?movieId=134130', '블랙머니', 9.1, '2019.11.13'],
#  ['123582',
#   '24',
#   '/moviedb/main?movieId=123582',
#   '터미네이터: 다크 페이트',
#   7.8,
#   '2019.10.30'],
#  ['115191', '25', '/moviedb/main?movieId=115191', '사바하', 7.3, '2019.02.20'],
#  ['122593',
#   '26',
#   '/moviedb/main?movieId=122593',
#   '타짜: 원 아이드 잭',
#   5.2,
#   '2019.09.11'],
#  ['124804',
#   '27',
#   '/moviedb/main?movieId=124804',
#   '신의 한 수: 귀수편',
#   6.8,
#   '2019.11.07'],
#  ['106442',
#   '28',
#   '/moviedb/main?movieId=106442',
#   '알리타: 배틀 엔젤',
#   8.3,
#   '2019.02.05'],
#  ['116230', '29', '/moviedb/main?movieId=116230', '내안의 그놈', 7.8, '2019.01.09'],
#  ['113877', '30', '/moviedb/main?movieId=113877', '뺑반', 6.2, '2019.01.30'],
#  ['126721', '31', '/moviedb/main?movieId=126721', '변신', 7.5, '2019.08.21'],
#  ['118493',
#   '32',
#   '/moviedb/main?movieId=118493',
#   '주먹왕 랄프 2: 인터넷 속으로',
#   7.6,
#   '2019.01.03'],
#  ['120834', '33', '/moviedb/main?movieId=120834', '걸캅스', 6.5, '2019.05.09'],
#  ['119238', '34', '/moviedb/main?movieId=119238', '사자', 6.9, '2019.07.31'],
#  ['94484', '35', '/moviedb/main?movieId=94484', '아쿠아맨', 7.5, '2018.12.19'],
#  ['121982',
#   '36',
#   '/moviedb/main?movieId=121982',
#   '드래곤 길들이기 3',
#   8.3,
#   '2019.01.30'],
#  ['121368',
#   '37',
#   '/moviedb/main?movieId=121368',
#   '나의 특별한 형제',
#   8.6,
#   '2019.05.01'],
#  ['121721', '38', '/moviedb/main?movieId=121721', '어스', 5.7, '2019.03.27'],
#  ['111120',
#   '39',
#   '/moviedb/main?movieId=111120',
#   '말레피센트 2',
#   7.5,
#   '2019.10.17'],
#  ['124812',
#   '40',
#   '/moviedb/main?movieId=124812',
#   '유열의 음악앨범',
#   7.0,
#   '2019.08.28'],
#  ['125049', '41', '/moviedb/main?movieId=125049', '퍼펙트맨', 6.9, '2019.10.02'],
#  ['128372',
#   '42',
#   '/moviedb/main?movieId=128372',
#   '포드 V 페라리',
#   8.7,
#   '2019.12.04'],
#  ['120146', '43', '/moviedb/main?movieId=120146', '생일', 8.6, '2019.04.03'],
#  ['122541',
#   '44',
#   '/moviedb/main?movieId=122541',
#   '힘을 내요 미스터 리',
#   7.7,
#   '2019.09.11'],
#  ['128434',
#   '45',
#   '/moviedb/main?movieId=128434',
#   '항거:유관순 이야기',
#   9.0,
#   '2019.02.27'],
#  ['124178',
#   '46',
#   '/moviedb/main?movieId=124178',
#   '장사리 : 잊혀진 영웅들',
#   7.4,
#   '2019.09.25'],
#  ['126143',
#   '47',
#   '/moviedb/main?movieId=126143',
#   '마이펫의 이중생활 2',
#   7.9,
#   '2019.07.31'],
#  ['124803',
#   '48',
#   '/moviedb/main?movieId=124803',
#   '롱 리브 더 킹: 목포 영웅',
#   7.6,
#   '2019.06.19'],
#  ['131271',
#   '49',
#   '/moviedb/main?movieId=131271',
#   '쥬만지: 넥스트 레벨',
#   5.9,
#   '2019.12.11'],
#  ['126253',
#   '50',
#   '/moviedb/main?movieId=126253',
#   '존 윅 3: 파라벨룸',
#   6.9,
#   '2019.06.26']]

# %%
mv2019 = mvlist(2019)
mv2018 = mvlist(2018)

mv = mv2018+mv2019

for line in mv :
  print(line)

with open('/content/drive/My Drive/Colab Notebooks/PythonWork/PythonBasic/work/Day06/movielist.txt', 'w') as fp:
    for line in mv:
      line = str(line).replace('[','').replace(']','')+'\n' 
      fp.write(line)
# Out:
# ['120166', '1', '/moviedb/main?movieId=120166', '신과함께-인과 연', 6.8, '2018.08.01']
# ['93251', '2', '/moviedb/main?movieId=93251', '어벤져스: 인피니티 워', 7.6, '2018.04.25']
# ['115280', '3', '/moviedb/main?movieId=115280', '보헤미안 랩소디', 8.9, '2018.10.31']
# ['99611', '4', '/moviedb/main?movieId=99611', '미션 임파서블: 폴아웃', 8.1, '2018.07.25']
# ['73003', '5', '/moviedb/main?movieId=73003', '신과함께-죄와 벌', 7.0, '2017.12.20']
# ['108035', '6', '/moviedb/main?movieId=108035', '쥬라기 월드: 폴른 킹덤', 7.1, '2018.06.06']
# ['110746', '7', '/moviedb/main?movieId=110746', '앤트맨과 와스프', 7.4, '2018.07.04']
# ['110556', '8', '/moviedb/main?movieId=110556', '안시성', 7.6, '2018.09.19']
# ['98033', '9', '/moviedb/main?movieId=98033', '블랙 팬서', 6.1, '2018.02.14']
# ['117910', '10', '/moviedb/main?movieId=117910', '완벽한 타인', 7.5, '2018.10.31']
# ['108595', '11', '/moviedb/main?movieId=108595', '1987', 9.5, '2017.12.27']
# ['108633', '12', '/moviedb/main?movieId=108633', '독전', 6.5, '2018.05.22']
# ['109169', '13', '/moviedb/main?movieId=109169', '공작', 8.3, '2018.08.08']
# ['112415', '14', '/moviedb/main?movieId=112415', '베놈', 7.1, '2018.10.03']
# ['109924', '15', '/moviedb/main?movieId=109924', '암수살인', 7.6, '2018.10.03']
# ['102301', '16', '/moviedb/main?movieId=102301', '데드풀 2', 6.8, '2018.05.16']
# ['114124', '17', '/moviedb/main?movieId=114124', '국가부도의 날', 8.1, '2018.11.28']
# ['110929', '18', '/moviedb/main?movieId=110929', '코코', 8.9, '2018.01.11']
# ['94484', '19', '/moviedb/main?movieId=94484', '아쿠아맨', 7.5, '2018.12.19']
# ['108632', '20', '/moviedb/main?movieId=108632', '그것만이 내 세상', 8.7, '2018.01.17']
# ['111293', '21', '/moviedb/main?movieId=111293', '마녀', 8.0, '2018.06.27']
# ['112705', '22', '/moviedb/main?movieId=112705', '탐정: 리턴즈', 7.4, '2018.06.13']
# ['117020', '23', '/moviedb/main?movieId=117020', '인크레더블 2', 8.0, '2018.07.18']
# ['117952', '24', '/moviedb/main?movieId=117952', '서치', 8.3, '2018.08.29']
# ['113862', '25', '/moviedb/main?movieId=113862', '너의 결혼식', 7.3, '2018.08.22']
# ['118604', '26', '/moviedb/main?movieId=118604', '곤지암', 4.9, '2018.03.28']
# ['115112', '27', '/moviedb/main?movieId=115112', '지금 만나러 갑니다', 7.9, '2018.03.14']
# ['111723', '28', '/moviedb/main?movieId=111723', '목격자', 5.3, '2018.08.15']
# ['113686', '29', '/moviedb/main?movieId=113686', '조선명탐정: 흡혈괴마의 비밀', 6.6, '2018.02.08']
# ['111490', '30', '/moviedb/main?movieId=111490', '신비한 동물들과 그린델왈드의 범죄', 5.9, '2018.11.14']
# ['115769', '31', '/moviedb/main?movieId=115769', '메이즈 러너: 데스 큐어', 7.1, '2018.01.17']
# ['112899', '32', '/moviedb/main?movieId=112899', '맘마미아!2', 7.8, '2018.08.08']
# ['96030', '33', '/moviedb/main?movieId=96030', '레디 플레이어 원', 7.9, '2018.03.28']
# ['111569', '34', '/moviedb/main?movieId=111569', '명당', 6.6, '2018.09.19']
# ['112447', '35', '/moviedb/main?movieId=112447', '협상', 7.1, '2018.09.19']
# ['108037', '36', '/moviedb/main?movieId=108037', '마약왕', 5.5, '2018.12.19']
# ['107638', '37', '/moviedb/main?movieId=107638', '쥬만지: 새로운 세계', 7.4, '2018.01.03']
# ['110097', '38', '/moviedb/main?movieId=110097', '창궐', 5.5, '2018.10.25']
# ['118313', '39', '/moviedb/main?movieId=118313', '성난황소', 6.3, '2018.11.22']
# ['118159', '40', '/moviedb/main?movieId=118159', '도어락', 6.3, '2018.12.05']
# ['106307', '41', '/moviedb/main?movieId=106307', '리틀 포레스트', 8.4, '2018.02.28']
# ['108886', '42', '/moviedb/main?movieId=108886', '골든슬럼버', 5.2, '2018.02.14']
# ['108275', '43', '/moviedb/main?movieId=108275', '램페이지', 6.7, '2018.04.12']
# ['95501', '44', '/moviedb/main?movieId=95501', '궁합', 6.4, '2018.02.28']
# ['108442', '45', '/moviedb/main?movieId=108442', '오션스8', 6.8, '2018.06.13']
# ['111294', '46', '/moviedb/main?movieId=111294', '사라진 밤', 6.9, '2018.03.07']
# ['112060', '47', '/moviedb/main?movieId=112060', '스윙키즈', 8.5, '2018.12.19']
# ['110548', '48', '/moviedb/main?movieId=110548', '바람 바람 바람', 6.3, '2018.04.05']
# ['114542', '49', '/moviedb/main?movieId=114542', 'PMC: 더 벙커', 5.3, '2018.12.26']
# ['111384', '50', '/moviedb/main?movieId=111384', '범블비', 7.5, '2018.12.25']
# ['119859', '1', '/moviedb/main?movieId=119859', '극한직업', 7.4, '2019.01.23']
# ['93252', '2', '/moviedb/main?movieId=93252', '어벤져스: 엔드게임', 7.8, '2019.04.24']
# ['93004', '3', '/moviedb/main?movieId=93004', '겨울왕국 2', 7.4, '2019.11.21']
# ['115601', '4', '/moviedb/main?movieId=115601', '알라딘', 8.4, '2019.05.23']
# ['111292', '5', '/moviedb/main?movieId=111292', '기생충', 7.9, '2019.05.30']
# ['121137', '6', '/moviedb/main?movieId=121137', '엑시트', 7.7, '2019.07.31']
# ['122542', '7', '/moviedb/main?movieId=122542', '스파이더맨: 파 프롬 홈', 6.5, '2019.07.02']
# ['133855', '8', '/moviedb/main?movieId=133855', '백두산', 6.5, '2019.12.19']
# ['101393', '9', '/moviedb/main?movieId=101393', '캡틴 마블', 6.3, '2019.03.06']
# ['125080', '10', '/moviedb/main?movieId=125080', '조커', 7.7, '2019.10.02']
# ['121160', '11', '/moviedb/main?movieId=121160', '봉오동 전투', 8.8, '2019.08.07']
# ['116523', '12', '/moviedb/main?movieId=116523', '라이온 킹', 7.4, '2019.07.17']
# ['123374', '13', '/moviedb/main?movieId=123374', '나쁜 녀석들: 더 무비', 6.3, '2019.09.11']
# ['124806', '14', '/moviedb/main?movieId=124806', '82년생 김지영', 6.7, '2019.10.23']
# ['127242', '15', '/moviedb/main?movieId=127242', '분노의 질주: 홉스&쇼', 7.0, '2019.08.14']
# ['123556', '16', '/moviedb/main?movieId=123556', '토이 스토리 4', 8.6, '2019.06.20']
# ['110875', '17', '/moviedb/main?movieId=110875', '돈', 6.7, '2019.03.20']
# ['121919', '18', '/moviedb/main?movieId=121919', '악인전', 7.4, '2019.05.15']
# ['127878', '19', '/moviedb/main?movieId=127878', '가장 보통의 연애', 7.4, '2019.10.02']
# ['118907', '20', '/moviedb/main?movieId=118907', '말모이', 9.1, '2019.01.09']
# ['121408', '21', '/moviedb/main?movieId=121408', '증인', 9.3, '2019.02.13']
# ['128397', '22', '/moviedb/main?movieId=128397', '시동', 7.6, '2019.12.18']
# ['134130', '23', '/moviedb/main?movieId=134130', '블랙머니', 9.1, '2019.11.13']
# ['123582', '24', '/moviedb/main?movieId=123582', '터미네이터: 다크 페이트', 7.8, '2019.10.30']
# ['115191', '25', '/moviedb/main?movieId=115191', '사바하', 7.3, '2019.02.20']
# ['122593', '26', '/moviedb/main?movieId=122593', '타짜: 원 아이드 잭', 5.2, '2019.09.11']
# ['124804', '27', '/moviedb/main?movieId=124804', '신의 한 수: 귀수편', 6.8, '2019.11.07']
# ['106442', '28', '/moviedb/main?movieId=106442', '알리타: 배틀 엔젤', 8.3, '2019.02.05']
# ['116230', '29', '/moviedb/main?movieId=116230', '내안의 그놈', 7.8, '2019.01.09']
# ['113877', '30', '/moviedb/main?movieId=113877', '뺑반', 6.2, '2019.01.30']
# ['126721', '31', '/moviedb/main?movieId=126721', '변신', 7.5, '2019.08.21']
# ['118493', '32', '/moviedb/main?movieId=118493', '주먹왕 랄프 2: 인터넷 속으로', 7.6, '2019.01.03']
# ['120834', '33', '/moviedb/main?movieId=120834', '걸캅스', 6.5, '2019.05.09']
# ['119238', '34', '/moviedb/main?movieId=119238', '사자', 6.9, '2019.07.31']
# ['94484', '35', '/moviedb/main?movieId=94484', '아쿠아맨', 7.5, '2018.12.19']
# ['121982', '36', '/moviedb/main?movieId=121982', '드래곤 길들이기 3', 8.3, '2019.01.30']
# ['121368', '37', '/moviedb/main?movieId=121368', '나의 특별한 형제', 8.6, '2019.05.01']
# ['121721', '38', '/moviedb/main?movieId=121721', '어스', 5.7, '2019.03.27']
# ['111120', '39', '/moviedb/main?movieId=111120', '말레피센트 2', 7.5, '2019.10.17']
# ['124812', '40', '/moviedb/main?movieId=124812', '유열의 음악앨범', 7.0, '2019.08.28']
# ['125049', '41', '/moviedb/main?movieId=125049', '퍼펙트맨', 6.9, '2019.10.02']
# ['128372', '42', '/moviedb/main?movieId=128372', '포드 V 페라리', 8.7, '2019.12.04']
# ['120146', '43', '/moviedb/main?movieId=120146', '생일', 8.6, '2019.04.03']
# ['122541', '44', '/moviedb/main?movieId=122541', '힘을 내요 미스터 리', 7.7, '2019.09.11']
# ['128434', '45', '/moviedb/main?movieId=128434', '항거:유관순 이야기', 9.0, '2019.02.27']
# ['124178', '46', '/moviedb/main?movieId=124178', '장사리 : 잊혀진 영웅들', 7.4, '2019.09.25']
# ['126143', '47', '/moviedb/main?movieId=126143', '마이펫의 이중생활 2', 7.9, '2019.07.31']
# ['124803', '48', '/moviedb/main?movieId=124803', '롱 리브 더 킹: 목포 영웅', 7.6, '2019.06.19']
# ['131271', '49', '/moviedb/main?movieId=131271', '쥬만지: 넥스트 레벨', 5.9, '2019.12.11']
# ['126253', '50', '/moviedb/main?movieId=126253', '존 윅 3: 파라벨룸', 6.9, '2019.06.26']

# %%
with open('/content/drive/My Drive/Colab Notebooks/PythonWork/PythonBasic/work/Day06/movielist.txt', encoding='utf-8') as fp:
  data = fp.readlines()
for line in data :
  print(line)
# Out:
# '120166', '1', '/moviedb/main?movieId=120166', '신과함께-인과 연', 6.8, '2018.08.01'
#
# '93251', '2', '/moviedb/main?movieId=93251', '어벤져스: 인피니티 워', 7.6, '2018.04.25'
#
# '115280', '3', '/moviedb/main?movieId=115280', '보헤미안 랩소디', 8.9, '2018.10.31'
#
# '99611', '4', '/moviedb/main?movieId=99611', '미션 임파서블: 폴아웃', 8.1, '2018.07.25'
#
# '73003', '5', '/moviedb/main?movieId=73003', '신과함께-죄와 벌', 7.0, '2017.12.20'
#
# '108035', '6', '/moviedb/main?movieId=108035', '쥬라기 월드: 폴른 킹덤', 7.1, '2018.06.06'
#
# '110746', '7', '/moviedb/main?movieId=110746', '앤트맨과 와스프', 7.4, '2018.07.04'
#
# '110556', '8', '/moviedb/main?movieId=110556', '안시성', 7.6, '2018.09.19'
#
# '98033', '9', '/moviedb/main?movieId=98033', '블랙 팬서', 6.1, '2018.02.14'
#
# '117910', '10', '/moviedb/main?movieId=117910', '완벽한 타인', 7.5, '2018.10.31'
#
# '108595', '11', '/moviedb/main?movieId=108595', '1987', 9.5, '2017.12.27'
#
# '108633', '12', '/moviedb/main?movieId=108633', '독전', 6.5, '2018.05.22'
#
# '109169', '13', '/moviedb/main?movieId=109169', '공작', 8.3, '2018.08.08'
#
# '112415', '14', '/moviedb/main?movieId=112415', '베놈', 7.1, '2018.10.03'
#
# '109924', '15', '/moviedb/main?movieId=109924', '암수살인', 7.6, '2018.10.03'
#
# '102301', '16', '/moviedb/main?movieId=102301', '데드풀 2', 6.8, '2018.05.16'
#
# '114124', '17', '/moviedb/main?movieId=114124', '국가부도의 날', 8.1, '2018.11.28'
#
# '110929', '18', '/moviedb/main?movieId=110929', '코코', 8.9, '2018.01.11'
#
# '94484', '19', '/moviedb/main?movieId=94484', '아쿠아맨', 7.5, '2018.12.19'
#
# '108632', '20', '/moviedb/main?movieId=108632', '그것만이 내 세상', 8.7, '2018.01.17'
#
# '111293', '21', '/moviedb/main?movieId=111293', '마녀', 8.0, '2018.06.27'
#
# '112705', '22', '/moviedb/main?movieId=112705', '탐정: 리턴즈', 7.4, '2018.06.13'
#
# '117020', '23', '/moviedb/main?movieId=117020', '인크레더블 2', 8.0, '2018.07.18'
#
# '117952', '24', '/moviedb/main?movieId=117952', '서치', 8.3, '2018.08.29'
#
# '113862', '25', '/moviedb/main?movieId=113862', '너의 결혼식', 7.3, '2018.08.22'
#
# '118604', '26', '/moviedb/main?movieId=118604', '곤지암', 4.9, '2018.03.28'
#
# '115112', '27', '/moviedb/main?movieId=115112', '지금 만나러 갑니다', 7.9, '2018.03.14'
#
# '111723', '28', '/moviedb/main?movieId=111723', '목격자', 5.3, '2018.08.15'
#
# '113686', '29', '/moviedb/main?movieId=113686', '조선명탐정: 흡혈괴마의 비밀', 6.6, '2018.02.08'
#
# '111490', '30', '/moviedb/main?movieId=111490', '신비한 동물들과 그린델왈드의 범죄', 5.9, '2018.11.14'
#
# '115769', '31', '/moviedb/main?movieId=115769', '메이즈 러너: 데스 큐어', 7.1, '2018.01.17'
#
# '112899', '32', '/moviedb/main?movieId=112899', '맘마미아!2', 7.8, '2018.08.08'
#
# '96030', '33', '/moviedb/main?movieId=96030', '레디 플레이어 원', 7.9, '2018.03.28'
#
# '111569', '34', '/moviedb/main?movieId=111569', '명당', 6.6, '2018.09.19'
#
# '112447', '35', '/moviedb/main?movieId=112447', '협상', 7.1, '2018.09.19'
#
# '108037', '36', '/moviedb/main?movieId=108037', '마약왕', 5.5, '2018.12.19'
#
# '107638', '37', '/moviedb/main?movieId=107638', '쥬만지: 새로운 세계', 7.4, '2018.01.03'
#
# '110097', '38', '/moviedb/main?movieId=110097', '창궐', 5.5, '2018.10.25'
#
# '118313', '39', '/moviedb/main?movieId=118313', '성난황소', 6.3, '2018.11.22'
#
# '118159', '40', '/moviedb/main?movieId=118159', '도어락', 6.3, '2018.12.05'
#
# '106307', '41', '/moviedb/main?movieId=106307', '리틀 포레스트', 8.4, '2018.02.28'
#
# '108886', '42', '/moviedb/main?movieId=108886', '골든슬럼버', 5.2, '2018.02.14'
#
# '108275', '43', '/moviedb/main?movieId=108275', '램페이지', 6.7, '2018.04.12'
#
# '95501', '44', '/moviedb/main?movieId=95501', '궁합', 6.4, '2018.02.28'
#
# '108442', '45', '/moviedb/main?movieId=108442', '오션스8', 6.8, '2018.06.13'
#
# '111294', '46', '/moviedb/main?movieId=111294', '사라진 밤', 6.9, '2018.03.07'
#
# '112060', '47', '/moviedb/main?movieId=112060', '스윙키즈', 8.5, '2018.12.19'
#
# '110548', '48', '/moviedb/main?movieId=110548', '바람 바람 바람', 6.3, '2018.04.05'
#
# '114542', '49', '/moviedb/main?movieId=114542', 'PMC: 더 벙커', 5.3, '2018.12.26'
#
# '111384', '50', '/moviedb/main?movieId=111384', '범블비', 7.5, '2018.12.25'
#
# '119859', '1', '/moviedb/main?movieId=119859', '극한직업', 7.4, '2019.01.23'
#
# '93252', '2', '/moviedb/main?movieId=93252', '어벤져스: 엔드게임', 7.8, '2019.04.24'
#
# '93004', '3', '/moviedb/main?movieId=93004', '겨울왕국 2', 7.4, '2019.11.21'
#
# '115601', '4', '/moviedb/main?movieId=115601', '알라딘', 8.4, '2019.05.23'
#
# '111292', '5', '/moviedb/main?movieId=111292', '기생충', 7.9, '2019.05.30'
#
# '121137', '6', '/moviedb/main?movieId=121137', '엑시트', 7.7, '2019.07.31'
#
# '122542', '7', '/moviedb/main?movieId=122542', '스파이더맨: 파 프롬 홈', 6.5, '2019.07.02'
#
# '133855', '8', '/moviedb/main?movieId=133855', '백두산', 6.5, '2019.12.19'
#
# '101393', '9', '/moviedb/main?movieId=101393', '캡틴 마블', 6.3, '2019.03.06'
#
# '125080', '10', '/moviedb/main?movieId=125080', '조커', 7.7, '2019.10.02'
#
# '121160', '11', '/moviedb/main?movieId=121160', '봉오동 전투', 8.8, '2019.08.07'
#
# '116523', '12', '/moviedb/main?movieId=116523', '라이온 킹', 7.4, '2019.07.17'
#
# '123374', '13', '/moviedb/main?movieId=123374', '나쁜 녀석들: 더 무비', 6.3, '2019.09.11'
#
# '124806', '14', '/moviedb/main?movieId=124806', '82년생 김지영', 6.7, '2019.10.23'
#
# '127242', '15', '/moviedb/main?movieId=127242', '분노의 질주: 홉스&쇼', 7.0, '2019.08.14'
#
# '123556', '16', '/moviedb/main?movieId=123556', '토이 스토리 4', 8.6, '2019.06.20'
#
# '110875', '17', '/moviedb/main?movieId=110875', '돈', 6.7, '2019.03.20'
#
# '121919', '18', '/moviedb/main?movieId=121919', '악인전', 7.4, '2019.05.15'
#
# '127878', '19', '/moviedb/main?movieId=127878', '가장 보통의 연애', 7.4, '2019.10.02'
#
# '118907', '20', '/moviedb/main?movieId=118907', '말모이', 9.1, '2019.01.09'
#
# '121408', '21', '/moviedb/main?movieId=121408', '증인', 9.3, '2019.02.13'
#
# '128397', '22', '/moviedb/main?movieId=128397', '시동', 7.6, '2019.12.18'
#
# '134130', '23', '/moviedb/main?movieId=134130', '블랙머니', 9.1, '2019.11.13'
#
# '123582', '24', '/moviedb/main?movieId=123582', '터미네이터: 다크 페이트', 7.8, '2019.10.30'
#
# '115191', '25', '/moviedb/main?movieId=115191', '사바하', 7.3, '2019.02.20'
#
# '122593', '26', '/moviedb/main?movieId=122593', '타짜: 원 아이드 잭', 5.2, '2019.09.11'
#
# '124804', '27', '/moviedb/main?movieId=124804', '신의 한 수: 귀수편', 6.8, '2019.11.07'
#
# '106442', '28', '/moviedb/main?movieId=106442', '알리타: 배틀 엔젤', 8.3, '2019.02.05'
#
# '116230', '29', '/moviedb/main?movieId=116230', '내안의 그놈', 7.8, '2019.01.09'
#
# '113877', '30', '/moviedb/main?movieId=113877', '뺑반', 6.2, '2019.01.30'
#
# '126721', '31', '/moviedb/main?movieId=126721', '변신', 7.5, '2019.08.21'
#
# '118493', '32', '/moviedb/main?movieId=118493', '주먹왕 랄프 2: 인터넷 속으로', 7.6, '2019.01.03'
#
# '120834', '33', '/moviedb/main?movieId=120834', '걸캅스', 6.5, '2019.05.09'
#
# '119238', '34', '/moviedb/main?movieId=119238', '사자', 6.9, '2019.07.31'
#
# '94484', '35', '/moviedb/main?movieId=94484', '아쿠아맨', 7.5, '2018.12.19'
#
# '121982', '36', '/moviedb/main?movieId=121982', '드래곤 길들이기 3', 8.3, '2019.01.30'
#
# '121368', '37', '/moviedb/main?movieId=121368', '나의 특별한 형제', 8.6, '2019.05.01'
#
# '121721', '38', '/moviedb/main?movieId=121721', '어스', 5.7, '2019.03.27'
#
# '111120', '39', '/moviedb/main?movieId=111120', '말레피센트 2', 7.5, '2019.10.17'
#
# '124812', '40', '/moviedb/main?movieId=124812', '유열의 음악앨범', 7.0, '2019.08.28'
#
# '125049', '41', '/moviedb/main?movieId=125049', '퍼펙트맨', 6.9, '2019.10.02'
#
# '128372', '42', '/moviedb/main?movieId=128372', '포드 V 페라리', 8.7, '2019.12.04'
#
# '120146', '43', '/moviedb/main?movieId=120146', '생일', 8.6, '2019.04.03'
#
# '122541', '44', '/moviedb/main?movieId=122541', '힘을 내요 미스터 리', 7.7, '2019.09.11'
#
# '128434', '45', '/moviedb/main?movieId=128434', '항거:유관순 이야기', 9.0, '2019.02.27'
#
# '124178', '46', '/moviedb/main?movieId=124178', '장사리 : 잊혀진 영웅들', 7.4, '2019.09.25'
#
# '126143', '47', '/moviedb/main?movieId=126143', '마이펫의 이중생활 2', 7.9, '2019.07.31'
#
# '124803', '48', '/moviedb/main?movieId=124803', '롱 리브 더 킹: 목포 영웅', 7.6, '2019.06.19'
#
# '131271', '49', '/moviedb/main?movieId=131271', '쥬만지: 넥스트 레벨', 5.9, '2019.12.11'
#
# '126253', '50', '/moviedb/main?movieId=126253', '존 윅 3: 파라벨룸', 6.9, '2019.06.26'

# %%
def mvlist2(year):
    mvlt = [] 
    url = 'https://movie.daum.net/boxoffice/yearly?year=' + str(year)

    html = urlHtml(url)
    ul = html.select('.list_boxthumb > li')

    mvlt = []
    for li in ul :
        mvsp = li.getText().replace('\n\n', '').split('\n')
        mvsp[0] = str(year)
        #mvlt.append(mvsp)
        mvlt.append(mvsp[:len(mvsp)-1])

    return mvlt

# %%
mvlist2(2019)

# %%
with open('/content/drive/My Drive/PythonWork/PythonBasic/work/06/mv1.csv', 'r', encoding='utf-8') as fp :
    data = fp.readlines()

grade2019 = []
grade2018 = [] 
grade = {}

for line in data :
    #데이터 생성시 영화명에 ,를 제거하면 수행하지 않아도 됨
    #line = line.replace("', ", "'| ").replace(", '", "| '").replace('\n','')
    #line = line.replace("'","").split('|')

    line = line.split(',')
    print(line)
    if line[5].strip()[:4] == '2019' : grade2019.append(float(line[4]) )
    elif line[5].strip()[:4] == '2018' : grade2018.append(float(line[4]) )


print(grade2019)
print(grade2018)

plt.plot(grade2019, 'g', label='2019')
plt.plot(grade2018, 'b', label='2018')
plt.legend()
plt.show()
