# %%
with open('/content/drive/My Drive/PythonWork/PythonBasic/work/Day03/data.json', 'r', encoding ='utf-8') as fp:
  data = fp.read()

# %%
print(data)
print(type(data))
# Out:
# {
#     "request_id": "0",
#     "return_type": "omAnalysis",
#     "result": 0,
#     "reason": "",
#     "return_object": {
#         "query": "한국의 가을은 매우 아름답습니다.",
#         "type": "감성분석",
#         "score": 0.9999995231628418,
#         "label": "긍정"
#     },
#     "result_code": "success"
# }
# <class 'str'>

# %% [markdown]
# ### *str을* dict로 땡겨다 쓰고 싶다!!!!!!!
#  + json {키:값} 형태의 데이터 포멧, 흡사 파이썬의 딕셔너리
#  + str => 파이썬의 dict 로 변환

# %%
import json # 오류없음 성공
dt = json.loads(data)

print(dt)
print(type(dt))
# Out:
# {'request_id': '0', 'return_type': 'omAnalysis', 'result': 0, 'reason': '', 'return_object': {'query': '한국의 가을은 매우 아름답습니다.', 'type': '감성분석', 'score': 0.9999995231628418, 'label': '긍정'}, 'result_code': 'success'}
# <class 'dict'>

# %%
print(dt['result_code'])
# Out:
# success

# %%
rt = dt['return_object']
print(rt)

x = rt['score']
rate = f'{x*100 :.2f}%'
print(rt['query'],  rt['type'], '-' , rt['label'],  rate)

s = f"{rt['query']} : {rt['type']} - {rt['label']} ({rt['score']*100:0.2f})%" #f{}은 str
print(s)
# Out:
# {'query': '한국의 가을은 매우 아름답습니다.', 'type': '감성분석', 'score': 0.9999995231628418, 'label': '긍정'}
# 한국의 가을은 매우 아름답습니다. 감성분석 - 긍정 100.00%
# 한국의 가을은 매우 아름답습니다. : 감성분석 - 긍정 (100.00)%

# %%
jsonStr = json.dumps(jdata, indent='\t', ensure_ascii = False)
print(jsonStr)
print(type(jsonStr))
# Out:
# "{\n    \"request_id\": \"0\",\n    \"return_type\": \"omAnalysis\",\n    \"result\": 0,\n    \"reason\": \"\",\n    \"return_object\": {\n        \"query\": \"한국의 가을은 매우 아름답습니다.\",\n        \"type\": \"감성분석\",\n        \"score\": 0.9999995231628418,\n        \"label\": \"긍정\"\n    },\n    \"result_code\": \"success\"\n}"
# <class 'str'>
