# %%
from urllib.request import urlopen
import json

# %%
url =  'http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchDailyBoxOfficeList.json?key=430156241533f1d058c603178cc3ca0e&targetDt=20120101'
data = urlopen(url)
print(data)

data= urlopen(url).read
print(data)
# Out:
# ...
# <bound method HTTPResponse.read of <http.client.HTTPResponse object at 0x7f8dee0329b0>>

# %%
def movieRank(cdate) :
  mykey = '430156241533f1d058c603178cc3ca0e'

  url = 'http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchDailyBoxOfficeList.json'
  url = url + '?key=' +mykey
  url = url + '&targetDt=' + cdate

  #data = urlopen(url).read()
  data = urlopen(url).read().decode('utf-8')

  return data

# %%
cdate = input('날짜입력 : (yyyymmdd)')
movieData = movieRank(cdate)
print(movieData)
# Out:
# 날짜입력 : (yyyymmdd)20200701
# ...

# %%
dt = json.loads(movieData)

print(dt)
print(type(dt))
# Out:
# {'boxOfficeResult': {'boxofficeType': '일별 박스오피스', 'showRange': '20200701~20200701', 'dailyBoxOfficeList': [{'rnum': '1', 'rank': '1', 'rankInten': '0', 'rankOldAndNew': 'OLD', 'movieCd': '20193069', 'movieNm': '#살아있다', 'openDt': '2020-06-24', 'salesAmt': '428654500', 'salesShare': '56.5', 'salesInten': '-115194220', 'salesChange': '-21.2', 'salesAcc': '10384947960', 'audiCnt': '51663', 'audiInten': '-15435', 'audiChange': '-23', 'audiAcc': '1246625', 'scrnCnt': '1441', 'showCnt': '6137'}, {'rnum': '2', 'rank': '2', 'rankInten': '0', 'rankOldAndNew': 'OLD', 'movieCd': '20183813', 'movieNm': '결백', 'openDt': '2020-06-10', 'salesAmt': '74603320', 'salesShare': '9.8', 'salesInten': '-41243180', 'salesChange': '-35.6', 'salesAcc': '6656433160', 'audiCnt': '9244', 'audiInten': '-5499', 'audiChange': '-37.3', 'audiAcc': '752161', 'scrnCnt': '536', 'showCnt': '1323'}, {'rnum': '3', 'rank': '3', 'rankInten': '0', 'rankOldAndNew': 'NEW', 'movieCd': '20196201', 'movieNm': '소리꾼', 'openDt': '2020-
# ...

# %%
dl = dt['boxOfficeResult']['dailyBoxOfficeList']
 # print(type(dl))
for item in dl:
  # print(type(item))
  print(f"{item['rank']}위 : {item['movieNm']} ")
# Out:
# 1위 : #살아있다
# 2위 : 결백
# 3위 : 소리꾼
# 4위 : 다크 나이트
# 5위 : 온워드: 단 하루의 기적
# 6위 : 인베이젼 2020
# 7위 : 위대한 쇼맨
# 8위 : 부산행:익스텐디드
# 9위 : 해피 디 데이
# 10위 : 야구소녀
